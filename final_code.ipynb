# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
## Load libraries
import pandas as pd
import numpy as np

# %%
# Display options
pd.set_option('display.max_columns',50)

# %% [markdown]
# ## Read data

# %%
# train_data = pd.read_csv(r'C:\Users\ASHOK\Desktop\Amex\6659dcf08fed4_cheatsheet_2\663e2b6d54457_train_data_with_samplefeatures (1).csv')
# test_data = pd.read_csv(r'C:\Users\ASHOK\Desktop\Amex\6659dcf08fed4_cheatsheet_2\6644a1e287df6_test_data_with_samplefeatures.csv')

train_data = pd.read_csv(r'top5_train1.csv')
test_data = pd.read_csv(r'r2_test.csv')

# %%
train_data.shape
train_data.head(2)
# Out:
# (948, 132)
#    match id team1  team1_id  \
# 0   9331181    Ba     11283
# 1   8797060    Ed        20
#
#                                     team1_roster_ids  team2  team2_id  \
# 0  9373356.0:7857520.0:4232164.0:4566540.0:329940...  Hl Ph     12634
# 1  2089079.0:6139370.0:2076192.0:62432.0:2083409....  Wt Is        41
#
#                                     team2_roster_ids winner  winner_id  \
# 0  3500958.0:4231751.0:2735081.0:2035102.0:369833...  Hl Ph      12634
# 1  4690258.0:4069666.0:4230127.0:1942317.0:161392...     Ed         20
#
#    win_1_2  winner_0_1 toss winner toss decision        venue        city  \
# 0        2           1       Hl Ph         field  Hr Ct Sm Ie      Indore
# 1        1           0       Wt Is         field  Kn Ol Bn Bs  Bridgetown
#
#      match_dt         lighting     series_name   season  ground_id  \
# 0  20-10-2022  day/night match     Sd Mq Ai Ty  2022/23       7398
# 1  23-01-2022  day/night match  Ed tr of Wt Is  2021/22       1406
#
# ...

# %%
test_data.shape
test_data.head(2)
# Out:
# (207, 85)
#    match id  team1  team1_id  \
# 0   9272619  Me Ss     33949
# 1   9086958     Na       209
#
#                                     team1_roster_ids  team2  team2_id  \
# 0  4003390.0:7960994.0:3901078.0:2669316.0:373710...  Ht Hs     33928
# 1  5836452.0:8246468.0:7500324.0:3065502.0:363350...  Si La        69
#
#                                     team2_roster_ids toss winner  \
# 0  5843200.0:4223883.0:4655384.0:6249256.0:216159...       Ht Hs
# 1  7200598.0:4403531.0:3260564.0:2420760.0:239834...       Si La
#
#   toss decision           venue     city    match_dt         lighting  \
# 0         field        Be Ol Ht   Hobart  09-01-2023      night match
# 1         field  GA Sm Sh Gg Va  Geelong  16-10-2022  day/night match
#
#       series_name   season  ground_id  team_count_50runs_last15  \
# 0        Bg Bh Le  2022/23       6348                  0.666667
# 1  Si La tr of Aa  2022/23       3961                  0.142857
#
# ...

# %% [markdown]
# #### Create dependent column

# %%
train_data['winner_01'] = train_data.apply(lambda x: 1 if (x['team2']==x['winner']) else 0, axis=1)

# %% [markdown]
# #### Pre process

# %%
## Toss winner to numerical - 1 if team2 wins, else 0

train_data['toss_winner_01'] = np.where(train_data['toss winner']==train_data['team2'], 1, 0)
test_data['toss_winner_01'] = np.where(test_data['toss winner']==test_data['team2'], 1, 0)

# %%
## Toss decision - categorical - 1 if winner bats, 0 otherwise

train_data['toss_decision_01'] = np.where(train_data['toss decision']=='bat', 1, 0)
test_data['toss_decision_01'] = np.where(test_data['toss decision']=='bat', 1, 0)

# %%
import numpy as np

# Function to handle division and zero-check
def safe_divide(num, denom):
    if denom == 0:
        return 1 if num == 0 else 2
    return num / denom

# Calculate avg_st_rt_ratio
train_data['avg_st_rt_ratio'] = train_data.apply(
    lambda row: safe_divide(row['Average Strike Rate of Top 5 for team 1'], row['Average Strike Rate of Top 5 for team 2']),
    axis=1
)

# Calculate head_to_head_performance for batting average
train_data['avg_bat_avg_ratio'] = train_data.apply(
    lambda row: safe_divide(row['Average Batting Average of Top 5 for team 1'], row['Average Batting Average of Top 5 for team 2']),
    axis=1
)

# Calculate head_to_head_performance for economy rate
train_data['avg_eco_bowl_ratio'] = train_data.apply(
    lambda row: safe_divide(row['Average Economy of Bottom 5 Bowlers for team 1'], row['Average Economy of Bottom 5 Bowlers for team 2']),
    axis=1
)

# Calculate head_to_head_performance for bowling strike rate
train_data['avg_bowl_st_rt_ratio'] = train_data.apply(
    lambda row: safe_divide(row['Average Strike Rate of Bottom 5 Bowlers for team 1'], row['Average Strike Rate of Bottom 5 Bowlers for team 2']),
    axis=1
)

# Calculate the ultimate score
train_data['ultimate_score'] = (
    train_data[['random', 'scoreinf', 'score_ratio', 'final_day', 'achaa']].sum(axis=1) / 5
)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Read the training file into a pandas DataFrame
train_file = 'top5_train1.csv'  # Replace with your actual file path
df = pd.read_csv(train_file)

# Features to plot
features = ['team1_count_50runs_last15', 'team1_winp_last5', 'Total Wickets Taken by Team 1','team1_score']

# Plotting average values for each feature by win_1_2
for feature in features:
    # Calculate average values grouped by win_1_2
    max_y = df[feature].max()
    avg_values = df.groupby('win_1_2')[feature].mean()
    
    # Plotting
    plt.figure(figsize=(10, 6))
    avg_values.plot(marker='o', linestyle='-', color='b', markerfacecolor='r', markersize=8)  # Adjust plot style as needed
       
    plt.ylim(0, max_y)
    # Plot labels and title
    plt.title(f'Average {feature} by win_1_2')
    plt.xlabel('win_1_2')
    plt.ylabel(f'Average {feature}')
    plt.grid(True)
    plt.xticks(avg_values.index)  # Adjust x ticks if needed
    
    plt.show()
# Out:
# <Axes: xlabel='win_1_2'>
# (0.0, 27.0)
# Text(0.5, 1.0, 'Average team1_count_50runs_last15 by win_1_2')
# Text(0.5, 0, 'win_1_2')
# Text(0, 0.5, 'Average team1_count_50runs_last15')
# ([<matplotlib.axis.XTick at 0x1e8f4c75e10>,
# ...
#  [Text(1, 0, '1'), Text(2, 0, '2')])
# <Axes: xlabel='win_1_2'>
# (0.0, 100.0)
# Text(0.5, 1.0, 'Average team1_winp_last5 by win_1_2')
# Text(0.5, 0, 'win_1_2')
# Text(0, 0.5, 'Average team1_winp_last5')
# ([<matplotlib.axis.XTick at 0x1e8f6d1fb90>,
# ...
#  [Text(1, 0, '1'), Text(2, 0, '2')])
# <Axes: xlabel='win_1_2'>
# (0.0, 153.0)
# Text(0.5, 1.0, 'Average Total Wickets Taken by Team 1 by win_1_2')
# Text(0.5, 0, 'win_1_2')
# Text(0, 0.5, 'Average Total Wickets Taken by Team 1')
# ([<matplotlib.axis.XTick at 0x1e8f46e22d0>,
# ...
#  [Text(1, 0, '1'), Text(2, 0, '2')])
# <Axes: xlabel='win_1_2'>
# (0.0, 6860.544121)
# Text(0.5, 1.0, 'Average team1_score by win_1_2')
# Text(0.5, 0, 'win_1_2')
# Text(0, 0.5, 'Average team1_score')
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Read the training file into a pandas DataFrame
train_file = 'top5_train1.csv'  # Replace with your actual file path
df = pd.read_csv(train_file)

# Step 2: Select features for the pair plot
features = ['team1_count_50runs_last15', 'team1_winp_last5', 'Total Wickets Taken by Team 1', 'todu1','team2_count_50runs_last15', 'team2_winp_last5', 'Total Wickets Taken by Team 2', 'todu2']

# Step 3: Create a pair plot
sns.pairplot(df[features])
plt.suptitle('Pair Plot of Selected Features', y=1.02)  # Adjust title position
plt.show()
# Out:
# Text(0.5, 1.02, 'Pair Plot of Selected Features')

# %% [markdown]
# #### Selecting relevant columns

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Read the training file into a pandas DataFrame
train_file = 'top5_train1.csv'  # Replace with your actual file path
df = pd.read_csv(train_file)

# Step 2: Select features for histograms (all 28 features)
features = [
    'bowling1', 'bowling2', 'bowling_net', 'batting_net', 'team2only_avg_runs_last15', 
    'team1_winp_last5', 'team2_winp_last5', 'team1only_avg_runs_last15', 'team1_winp_team2_last15', 
    'team1_count_50runs_last15', 'team2_count_50runs_last15', 'Average Economy of Bottom 5 Bowlers for team 1', 
    'Average Economy of Bottom 5 Bowlers for team 2', 'Average Batting Average of Top 5 for team 1', 
    'ground_avg_runs_last15', 'achaa', 'aadb', 'more_boundary_1or2', 'todu', 
    'impact_score_ratio', 'score_ratio', 'Average Batting Average of Top 5 for team', 'random', 
    'Average Strike Rate of Top 5 for team 1', 'Average Strike Rate of Top 5 for team 2', 
    'Average Batting Average of Top 5 for team 2', 'Average Economy of Bottom 5 Bowlers for team net'
]

# Step 3: Calculate the number of rows and columns needed for subplots
num_features = len(features)
num_cols = 4  # Number of columns per row
num_rows = (num_features + num_cols - 1) // num_cols  # Calculate number of rows based on number of features

# Step 4: Create individual histograms for each feature
plt.figure(figsize=(20, 5 * num_rows))  # Adjust figure size based on number of features

for i, feature in enumerate(features, 1):
    plt.subplot(num_rows, num_cols, i)
    sns.histplot(df[feature], kde=True, bins=20, color='skyblue')
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# <Axes: >
# <Axes: xlabel='bowling1', ylabel='Count'>
# Text(0.5, 1.0, 'Histogram of bowling1')
# Text(0.5, 0, 'bowling1')
# Text(0, 0.5, 'Frequency')
# <Axes: >
# <Axes: xlabel='bowling2', ylabel='Count'>
# Text(0.5, 1.0, 'Histogram of bowling2')
# Text(0.5, 0, 'bowling2')
# Text(0, 0.5, 'Frequency')
# <Axes: >
# <Axes: xlabel='bowling_net', ylabel='Count'>
# Text(0.5, 1.0, 'Histogram of bowling_net')
# Text(0.5, 0, 'bowling_net')
# Text(0, 0.5, 'Frequency')
# <Axes: >
# <Axes: xlabel='batting_net', ylabel='Count'>
# Text(0.5, 1.0, 'Histogram of batting_net')
# Text(0.5, 0, 'batting_net')
# Text(0, 0.5, 'Frequency')
# <Axes: >
# <Axes: xlabel='team2only_avg_runs_last15', ylabel='Count'>
# Text(0.5, 1.0, 'Histogram of team2only_avg_runs_last15')
# Text(0.5, 0, 'team2only_avg_runs_last15')
# Text(0, 0.5, 'Frequency')
# <Axes: >
# <Axes: xlabel='team1_winp_last5', ylabel='Count'>
# Text(0.5, 1.0, 'Histogram of team1_winp_last5')
# Text(0.5, 0, 'team1_winp_last5')
# ...

# %%
#pawars features

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# Assuming train_data is a pandas DataFrame that contains the data

# Creating a figure with 2 subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(24, 7))

# First histogram for positive_score_ratio
sns.histplot(data=train_data, x='score_ratio', hue='winner_0_1', multiple='stack', palette={0: 'green', 1: 'red'}, bins=900, ax=axes[0])
axes[0].set_xlabel('score_ratio')
axes[0].set_ylabel('Count')
axes[0].set_title('Histogram of score_ratio for Winners and Non-Winners')
axes[0].set_xlim([-1, 3])

# Second histogram for inverse_score_ratio
sns.histplot(data=train_data, x='random', hue='winner_0_1', multiple='stack', palette={0: 'green', 1: 'red'}, bins=200, ax=axes[1])
axes[1].set_xlabel('random')
axes[1].set_ylabel('Count')
axes[1].set_title('Histogram of random for Winners and Non-Winners')
axes[1].set_xlim([-1, 3])

plt.tight_layout()  # Adjusts the layout to make space for titles and labels
plt.show()
# Out:
# <Axes: xlabel='score_ratio', ylabel='Count'>
# Text(0.5, 0, 'score_ratio')
# Text(0, 0.5, 'Count')
# Text(0.5, 1.0, 'Histogram of score_ratio for Winners and Non-Winners')
# (-1.0, 3.0)
# <Axes: xlabel='random', ylabel='Count'>
# Text(0.5, 0, 'random')
# Text(0, 0.5, 'Count')
# Text(0.5, 1.0, 'Histogram of random for Winners and Non-Winners')
# (-1.0, 3.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# Assuming train_data is a pandas DataFrame that contains the data

# Creating a figure with 2 subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(24, 7))

# First histogram for positive_score_ratio
sns.histplot(data=train_data, x='ultimate_score', hue='winner_0_1', multiple='stack', palette={0: 'green', 1: 'red'}, bins=900, ax=axes[0])
axes[0].set_xlabel('ultimate_score')
axes[0].set_ylabel('Count')
axes[0].set_title('Histogram of ultimate_score for Winners and Non-Winners')
axes[0].set_xlim([-1, 3])

# Second histogram for inverse_score_ratio
sns.histplot(data=train_data, x='achaa', hue='winner_0_1', multiple='stack', palette={0: 'green', 1: 'red'}, bins=200, ax=axes[1])
axes[1].set_xlabel('random')
axes[1].set_ylabel('Count')
axes[1].set_title('Histogram of random for Winners and Non-Winners')
axes[1].set_xlim([-1, 3])

plt.tight_layout()  # Adjusts the layout to make space for titles and labels
plt.show()
# Out:
# <Axes: xlabel='ultimate_score', ylabel='Count'>
# Text(0.5, 0, 'ultimate_score')
# Text(0, 0.5, 'Count')
# Text(0.5, 1.0, 'Histogram of ultimate_score for Winners and Non-Winners')
# (-1.0, 3.0)
# <Axes: xlabel='achaa', ylabel='Count'>
# Text(0.5, 0, 'random')
# Text(0, 0.5, 'Count')
# Text(0.5, 1.0, 'Histogram of random for Winners and Non-Winners')
# (-1.0, 3.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# Assuming train_data is a pandas DataFrame that contains the data

# Creating a figure with 2 subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(24, 7))

# First histogram for positive_score_ratio
sns.histplot(data=train_data, x='impact_score_ratio', hue='winner_0_1', multiple='stack', palette={0: 'green', 1: 'red'}, bins=900, ax=axes[0])
axes[0].set_xlabel('impact_score_ratio')
axes[0].set_ylabel('Count')
axes[0].set_title('Histogram of impact_score_ratio for Winners and Non-Winners')
axes[0].set_xlim([-2, 10])

plt.tight_layout()  # Adjusts the layout to make space for titles and labels
plt.show()
# Out:
# <Axes: xlabel='impact_score_ratio', ylabel='Count'>
# Text(0.5, 0, 'impact_score_ratio')
# Text(0, 0.5, 'Count')
# Text(0.5, 1.0, 'Histogram of impact_score_ratio for Winners and Non-Winners')
# (-2.0, 10.0)

# %%
# X,y = train_data[['team1_count_50runs_last15','team2_count_50runs_last15','team1_winp_last5','team2_winp_last5','team1_winp_team2_last15','ground_avg_runs_last15','bowling_khichadi','final_day','Average Batting Average of Top 5 for team 1','Average Batting Average of Top 5 for team 2','Average Economy of Bottom 5 Bowlers for team 1','Average Economy of Bottom 5 Bowlers for team 2','Average Strike Rate of Top 5 for team 1','Average Strike Rate of Top 5 for team 2','Average Strike Rate of Bottom 5 Bowlers for team 1','Average Strike Rate of Bottom 5 Bowlers for team 2']], train_data['winner_01']
# X,y = train_data[['more_boundary_1or2','ground_avg_runs_last15','friendly_to_ground','team1_winp_last5','team2_winp_last5','team1_winp_team2_last15','team_count_50runs_last15','bowling_khichadi','final_day','scoreinf','score_ratio','achaa','random']], train_data['winner_01']
# X,y = train_data[['team1_count_50runs_last15','team2_count_50runs_last15','team1_winp_last5','team2_winp_last5','team1_winp_team2_last15','team1only_avg_runs_last15','team2only_avg_runs_last15','ground_avg_runs_last15','Average Strike Rate of Top 5 for team 1','Average Batting Average of Top 5 for team 1','Average Strike Rate of Top 5 for team 2','Average Batting Average of Top 5 for team 2','Average Economy of Bottom 5 Bowlers for team 1','Average Economy of Bottom 5 Bowlers for team 2','impact_score_ratio','ultimate_score','bowling_khichadi','aadb']], train_data['winner_01']
# X,y = train_data[['team_count_50runs_last15','team_winp_last5','team1only_avg_runs_last15','team1_winp_team2_last15','ground_avg_runs_last15','avg_st_rt_ratio','avg_bat_avg_ratio','avg_eco_bowl_ratio','avg_bowl_st_rt_ratio','bowling1','bowling2','random','ultimate_score','final_day','aadb','hhhhh']], train_data['winner_01']

# X,y = train_data[['ultimate_score']], train_data['winner_01']
X,y = train_data[['bowling1','bowling2','bowling_net','batting_net','team2only_avg_runs_last15','team1_winp_last5','team2_winp_last5', 'team1only_avg_runs_last15', 'team1_winp_team2_last15', 'team1_count_50runs_last15','team2_count_50runs_last15','Average Economy of Bottom 5 Bowlers for team 1','Average Economy of Bottom 5 Bowlers for team 2','Average Batting Average of Top 5 for team 1',
                 'ground_avg_runs_last15','ultimate_score','achaa','aadb','more_boundary_1or2','todu','impact_score_ratio','score_ratio','Average Batting Average of Top 5 for team','random','Average Strike Rate of Top 5 for team 1','Average Strike Rate of Top 5 for team 2','Average Batting Average of Top 5 for team 2','Average Economy of Bottom 5 Bowlers for team net']], train_data['winner_01']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Combine X and y for the correlation matrix
data_combined = pd.concat([X, y], axis=1)

# Compute the correlation matrix
corr_matrix = data_combined.corr()

# Plot the heatmap
plt.figure(figsize=(22, 16))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap of Feature Correlations')
plt.show()
# Out:
# <Axes: >
# Text(0.5, 1.0, 'Heatmap of Feature Correlations')

# %%
X_test = test_data[X.columns.tolist()]

# %% [markdown]
# #### Imputation

# %%
X_nans = X.isna().sum().reset_index()
X_nans[X_nans[0]!=0]

X_test_nans = X_test.isna().sum().reset_index()
X_test_nans[X_test_nans[0]!=0]
# Out:
#                         index   0
# 0                    bowling1   6
# 1                    bowling2   3
# 4   team2only_avg_runs_last15   3
# 7   team1only_avg_runs_last15  21
# 14     ground_avg_runs_last15  53
#                         index   0
# 4   team2only_avg_runs_last15   3
# 14     ground_avg_runs_last15  10

# %%
X.fillna(0, inplace=True)
X_test.fillna(0, inplace=True)
# Out:
# C:\Users\91917\AppData\Local\Temp\ipykernel_7792\1698769224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.fillna(0, inplace=True)
# C:\Users\91917\AppData\Local\Temp\ipykernel_7792\1698769224.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.fillna(0, inplace=True)

# %%
X_nans = X.isna().sum().reset_index()
X_nans[X_nans[0]!=0]

X_test_nans = X_test.isna().sum().reset_index()
X_test_nans[X_test_nans[0]!=0]
# Out:
# Empty DataFrame
# Columns: [index, 0]
# Index: []
# Empty DataFrame
# Columns: [index, 0]
# Index: []

# %% [markdown]
# ### Stats

# %%
# scaling
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Assuming X_train and X_test are your feature matrices for training and testing respectively

# Fit the scaler on the training data
scaler.fit(X)

# Transform both the training and test data
X = scaler.transform(X)
X_test = scaler.transform(X_test)
# Out:
# StandardScaler()

# %% [markdown]
# ## Model

# %% [markdown]
# #### GBM

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# user-defined parameters

algo_name = 'xgboost;lightgbm'
is_ensemble = 'yes'
n_trees = '51;54'
depth = '3;3'
lr = '0.199;0.198'

# %% [markdown]
# XGBOOST

# %%
# pip install xgboost

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import numpy as np
from datetime import datetime

# %% [markdown]
# ##### Train

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import (
    accuracy_score, confusion_matrix, roc_curve, auc, classification_report, 
    precision_recall_curve, average_precision_score
)
from sklearn.calibration import calibration_curve
from sklearn.model_selection import learning_curve

# Define parameter values for XGBoost and LightGBM
xgb_params = {
    'learning_rate': 0.199,
    'n_estimators': 51,
    'max_depth': 3,
    'min_child_weight': 5,
    'subsample': 0.4,
    'colsample_bytree': 0.4,
    'reg_alpha': 1,
    'reg_lambda': 5,
    'objective': 'binary:logistic',
    'n_jobs': 4,
    'random_state': 28,
    'use_label_encoder': False,
    'eval_metric': 'logloss'
}

lgb_params = {
    'learning_rate': 0.198,
    'n_estimators': 54,
    'max_depth': 3,
    'min_child_weight': 3,
    'subsample': 0.4,
    'colsample_bytree': 1.0,
    'reg_alpha': 2,
    'reg_lambda': 3,
    'objective': 'binary',
    'n_jobs': 4,
    'random_state': 28
}

# Initialize the models with the provided parameters
xgb_model = XGBClassifier(**xgb_params)
lgb_model = LGBMClassifier(**lgb_params)

# Fit the models using all the data
xgb_model.fit(X, y)
lgb_model.fit(X, y)

# Create a Voting Classifier with the fitted models
clf_gbm = VotingClassifier(
    estimators=[
        ('xgb', xgb_model),
        ('lgb', lgb_model)
    ],
    voting='soft'  # Soft voting to consider the predicted probabilities
)

# Fit the ensemble model using all the data
clf_gbm.fit(X, y)

# Since there's no validation set, we'll use the training data itself for prediction and evaluation
y_pred = clf_gbm.predict(X)
accuracy = accuracy_score(y, y_pred)
print(f'Ensemble model accuracy: {accuracy:.4f}')

train_data['y_pred_01'] = clf_gbm.predict(X)
test_data['y_pred_01'] = clf_gbm.predict(X_test)

# Print classification report
print(classification_report(y, clf_gbm.predict(X), labels=[0, 1]))

# Confusion Matrix
cm = confusion_matrix(y, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0, 1], yticklabels=[0, 1])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# ROC Curve
y_prob = clf_gbm.predict_proba(X)[:, 1]
fpr, tpr, thresholds = roc_curve(y, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y, y_prob)
average_precision = average_precision_score(y, y_prob)
plt.figure()
plt.step(recall, precision, where='post', color='b', alpha=0.2, linestyle='-', linewidth=2)
plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title(f'Precision-Recall Curve: AP={average_precision:.2f}')
plt.show()

# Calibration Curve
prob_true, prob_pred = calibration_curve(y, y_prob, n_bins=10)
plt.figure()
plt.plot(prob_pred, prob_true, 's-', label='Calibrated model')
plt.plot([0, 1], [0, 1], 'k--', label='Perfectly calibrated')
plt.xlabel('Mean predicted probability')
plt.ylabel('Fraction of positives')
plt.title('Calibration Curve')
plt.legend(loc='best')
plt.show()

# Residual Plot
residuals = y - y_pred
plt.figure()
plt.hist(residuals, bins=50, alpha=0.5, color='g', edgecolor='black')
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residuals Histogram')
plt.show()
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.4, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.199, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=51,
#               n_jobs=4, num_parallel_tree=None, random_state=28, ...)
# [LightGBM] [Info] Number of positive: 480, number of negative: 468
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000210 seconds.
# ...

# %%
train_data['y_pred_01'] = clf_gbm.predict(X)
test_data['y_pred_01'] = clf_gbm.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y, clf_gbm.predict(X), labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       468
#            1       0.83      0.79      0.81       480
#
#     accuracy                           0.81       948
#    macro avg       0.81      0.81      0.81       948
# weighted avg       0.81      0.81      0.81       948

# %%
train_data['win_pred_score'] = clf_gbm.predict_proba(X)[:,1]
test_data['win_pred_score'] = clf_gbm.predict_proba(X_test)[:,1]

# %% [markdown]
# ##### Getting win_pred_score corresponding to winner team

# %%
train_data['win_pred_score'] = np.where( (train_data['y_pred_01']==0), (1-train_data['win_pred_score']), train_data['win_pred_score'])
test_data['win_pred_score'] = np.where( (test_data['y_pred_01']==0), (1-test_data['win_pred_score']), test_data['win_pred_score'])

# %% [markdown]
# ##### Getting winner_team_id from custom dependent column

# %%
train_data['win_pred_team_id'] = np.where( (train_data['y_pred_01']==0), (train_data['team1_id']), train_data['team2_id'])
test_data['win_pred_team_id'] = np.where( (test_data['y_pred_01']==0), (test_data['team1_id']), test_data['team2_id'])

# %% [markdown]
# #### Feature importance

# %%
# feature_importances = clf_gbm.feature_importances_

# # Create a DataFrame to hold feature names and their importance
# df_feat_importance = pd.DataFrame({
#     'feat_name': X.columns.tolist(),  # List of feature names from training data
#     'model_feat_imp_train': feature_importances  # Corresponding feature importances
# })

# # Sort the DataFrame by the feature importance in descending order
# df_feat_importance = df_feat_importance.sort_values(by='model_feat_imp_train', ascending=False).reset_index(drop=True)

# # Display the sorted feature importance DataFrame
# df_feat_importance

# %%
import pandas as pd

# Feature names
feature_names = [
    'bowling1','bowling2','bowling_net','batting_net','team2only_avg_runs_last15','team1_winp_last5',
    'team2_winp_last5','team1only_avg_runs_last15','team1_winp_team2_last15','team1_count_50runs_last15',
    'team2_count_50runs_last15','Average Economy of Bottom 5 Bowlers for team 1',
    'Average Economy of Bottom 5 Bowlers for team 2','Average Batting Average of Top 5 for team 1',
    'ground_avg_runs_last15','ultimate_score','achaa','aadb','more_boundary_1or2','todu',
    'impact_score_ratio','score_ratio','Average Batting Average of Top 5 for team','random',
    'Average Strike Rate of Top 5 for team 1','Average Strike Rate of Top 5 for team 2',
    'Average Batting Average of Top 5 for team 2','Average Economy of Bottom 5 Bowlers for team net'
]

xgb_feature_importances = xgb_model.feature_importances_
lgb_feature_importances = lgb_model.feature_importances_

# Average the importances
average_feature_importances = (xgb_feature_importances + lgb_feature_importances) / 2

# Create a DataFrame to hold feature names and their average importance
df_feat_importance = pd.DataFrame({
    'feat_name': feature_names,  # List of feature names from training data
    'model_feat_imp_train': average_feature_importances  # Corresponding average feature importances
})

# Sort the DataFrame by the feature importance in descending order
df_feat_importance = df_feat_importance.sort_values(by='model_feat_imp_train', ascending=False).reset_index(drop=True)

# Display the sorted feature importance DataFrame
print(df_feat_importance)
# Out:
#                                            feat_name  model_feat_imp_train
# 0                          team2only_avg_runs_last15             12.518407
# 1        Average Batting Average of Top 5 for team 1             12.020004
# 2                          team1only_avg_runs_last15             11.519312
# 3        Average Batting Average of Top 5 for team 2             11.518888
# 4                                           bowling1             11.019612
# 5                                           bowling2             10.018548
# 6                                        score_ratio              9.035355
# 7                             ground_avg_runs_last15              9.019013
# 8            Average Strike Rate of Top 5 for team 2              9.015552
# 9                                   team2_winp_last5              8.026574
# 10                                            random              7.520311
# ...

# %%
# top_15_features = df_feat_importance.head(15)
# top_15_features

# %%
# import matplotlib.pyplot as plt

# %%
# Create the plot
plt.figure(figsize=(30, 15))
plt.barh(df_feat_importance['feat_name'], df_feat_importance['model_feat_imp_train'], color='skyblue')
plt.xlabel('Feature Importance')
plt.ylabel('Feature Name')
plt.title('Feature Importances from Model')
plt.gca().invert_yaxis()  # To display the most important feature at the top
plt.show()
# Out:
# <BarContainer object of 28 artists>
# Text(0.5, 0, 'Feature Importance')
# Text(0, 0.5, 'Feature Name')
# Text(0.5, 1.0, 'Feature Importances from Model')

# %% [markdown]
# ## File preparation

# %% [markdown]
# #### File 1

# %%
train_data['dataset_type'] = 'train'
test_data['dataset_type'] = 'r1'

# %%
## refactor

df_file1 = pd.concat([test_data[['match id','dataset_type','win_pred_team_id','win_pred_score',] + list(df_feat_importance['feat_name'].head(10))], \
                     train_data[['match id','dataset_type','win_pred_team_id','win_pred_score',] + list(df_feat_importance['feat_name'].head(10))]])

renaming_dict = {}
for i,col in enumerate(list(df_feat_importance['feat_name'].head(10))):
    renaming_dict[col] = f'indep_feat_id{i+1}'
df_file1.rename(columns=renaming_dict, inplace=True)

for i in range(1,11):
    if f'indep_feat_id{i}' not in df_file1.columns:
        df_file1[f'indep_feat_id{i}'] = np.nan

df_file1['train_algorithm'] = algo_name
df_file1['is_ensemble'] = is_ensemble
df_file1['train_hps_trees'] = n_trees
df_file1['train_hps_depth'] = depth
df_file1['train_hps_lr'] = lr

# %%
df_file1.shape
df_file1.head()
# Out:
# (1155, 19)
#    match id dataset_type  win_pred_team_id  win_pred_score  indep_feat_id1  \
# 0   9272619           r1             33928        0.691766      164.888889
# 1   9086958           r1                69        0.511935      153.733333
# 2   9433654           r1              7573        0.599623      175.666667
# 3   9097248           r1             22763        0.516588      154.000000
# 4   9097234           r1             23750        0.670901      160.000000
#
#    indep_feat_id2  indep_feat_id3  indep_feat_id4  indep_feat_id5  \
# 0       24.289870      167.933333       27.525238        6.242696
# 1       28.083333      141.888889       30.354945        5.782463
# 2       30.350769      178.800000       38.892048        7.641253
# 3       22.344444      138.000000       36.620000        5.471287
# 4       20.839048      155.800000       27.200280        4.901162
#
#    indep_feat_id6  indep_feat_id7  indep_feat_id8  indep_feat_id9  \
# ...

# %% [markdown]
# #### File 2

# %%
feature_desc = {
    'team2only_avg_runs_last15': 'team2\'s avg inning runs in last 15 games',\
    'bowling2': 'Avg of Sum of wickets in last 15 matches for team 2',\
    'bowling1': 'Avg of Sum of wickets in last 15 matches for team 1',\
    'ground_avg_runs_last15': 'average runs scored in the ground in last 15 games',\
    'team1only_avg_runs_last15': 'team1\'s avg inning runs in last 15 games',\
    'score_ratio': 'assigning each team a score based on each player score and then taking ratio of individual team score based on skills of top 10 players',\
    'Average Economy of Bottom 5 Bowlers for team 1': 'Average Economy of Bottom 5 Bowlers for team 1',\
    'Average Batting Average of Top 5 for team 1': 'Average Batting Average of Top 5 for team 1',\
    'Average Batting Average of Top 5 for team 2': 'Average Batting Average of Top 5 for team 2',\
    'random': 'ratio of 70 30(normalizing batting and bowling details column and then assigning batting score and bowling score and taking ratio)',\
    'aadb': 'adding all top batsman stats and then taking ratio',\
    'impact_score_ratio': 'the ratio of total number of impact innings of all players in team 1 by that in team 2, Where impact innings is runs>30 with 140+ strikerate',\
    'team2_winp_last5': 'Ratio of team2\'s win % in last 5 games',\
    'Average Strike Rate of Top 5 for team 2': 'Average Strike Rate of Top 5 for team 2',\
    'achaa': 'adding number of players of the match, top exceptional players, top 5 batting score, bowling score of the team with some weightage to all and taking their ratio',\
    'Average Economy of Bottom 5 Bowlers for team 2': 'Average Economy of Bottom 5 Bowlers for team 2',\
    'Average Strike Rate of Top 5 for team 1': 'Average Strike Rate of Top 5 for team 1',\
    'team1_winp_last5': 'Ratio of team1\'s win % in last 5 games',\
    'team2_count_50runs_last15': 'Ratio of number of 50s by players in team2 in last 15 games',\
    'ultimate_score': 'average of random, scoreinf, score_ratio, final_day, achaa',\
    'team1_count_50runs_last15': 'Ratio of number of 50s by players in team1 in last 15 games',\
    'todu': 'number of exceptional players',\
    'more_boundary_1or2': 'more number of boundary by combined all players of team 1 or team 2',\
    'team1_winp_team2_last15': 'Team1\'s win percentage against Team2 in last 15 games',\
    'Average Batting Average of Top 5 for team': 'Ratio of Average Batting Average of Top 5 of both teams',\
    'batting_net': 'ratio of batting performance of both teams',\
    'Average Economy of Bottom 5 Bowlers for team net': 'Ratio of Average Economy of Bottom 5 Bowlers of both teams',\
    'bowling_net': 'ratio of bowling performance of both teams'
}

# %%
# df_feat_importance.rename(index={0:'feat_id'}, inplace=True)
df_file2 = df_feat_importance
df_file2['feat_id'] = [i+1 for i in df_file2.index]
df_file2['feat_rank_train'] = [i+1 for i in df_file2.index]
df_file2 = df_file2.set_index('feat_id')
df_file2['feat_description'] = df_file2['feat_name'].map(feature_desc)

# %%
df_file2
# Out:
#                                                 feat_name  \
# feat_id
# 1                               team2only_avg_runs_last15
# 2             Average Batting Average of Top 5 for team 1
# 3                               team1only_avg_runs_last15
# 4             Average Batting Average of Top 5 for team 2
# 5                                                bowling1
# 6                                                bowling2
# 7                                             score_ratio
# 8                                  ground_avg_runs_last15
# 9                 Average Strike Rate of Top 5 for team 2
# 10                                       team2_winp_last5
# 11                                                 random
# 12                Average Strike Rate of Top 5 for team 1
# 13         Average Economy of Bottom 5 Bowlers for team 2
# 14                                                   aadb
# 15                                                  achaa
# ...

# %% [markdown]
# ## Save

# %%
df_file1.to_csv('file1_en.csv', index=False)
df_file2.to_csv('file2_en.csv')
# df_file1.to_csv('file1_top5.csv', index=False)
# df_file2.to_csv('2024_DS_Track_File2_team.csv')
